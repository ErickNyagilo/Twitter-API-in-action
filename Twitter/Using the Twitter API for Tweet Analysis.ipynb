# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'cTWUpUPvifV2peY4dI7mEELru'
    Twitter['Consumer Secret'] = '9vcWwQZGqY31gUOBJltamCnNPS70nYvpNhqkGnqkrQFk16r3Xv'
    Twitter['Access Token'] = '759719180509777920-zyA6ydnmgQfzWhZLBSLsprxt7f3oW9b'
    Twitter['Access Token Secret'] = 'Rm1DlMNSlQC8Xi8fhczkGa498rB7OWJIT79yIMyXXrcgc'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000277FFFA6240>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#vaka5698',
#     'url': 'http://twitter.com/search?q=%23vaka5698',
#     'promoted_content': None,
#     'query': '%23vaka5698',
#     'tweet_volume': 61642},
#    {'name': '#FicaPrior',
#     'url': 'http://twitter.com/search?q=%23FicaPrior',
#     'promoted_content': None,
#     'query': '%23FicaPrior',
#     'tweet_volume': 333197},
#    {'name': '#TayyipErdoganNerede',
#     'url': 'http://twitter.com/search?q=%23TayyipErdoganNerede',
#     'promoted_content': None,
#     'query': '%23TayyipErdoganNerede',
#     'tweet_volume': 21131},
#    {'name': '#LockdownHouseParty',
#     'url': 'http://twitter.com/search?q=%23LockdownHouseParty',
#     'promoted_content': None,
#     'query': '%23LockdownHouseParty',
#     'tweet_volume': 19480},
#    {'name': '#CoronaLockdown',
#     'url': 'http://twitter.com/search?q=%23CoronaLockdown',
#     'promoted_content': None,
#     'query': '%23CoronaLockdown',
#     'tweet_volume': 231154},
#    {'name': 'Papa Francisco',
#     'url': 'http://twitter.com/search?q=%22Papa+Francisco%22',
#     'promoted_content': None,
#     'query': '%22Papa+Francisco%22',
#     'tweet_volume': 110021},
#    {'name': 'Doris',
#     'url': 'http://twitter.com/search?q=Doris',
#     'promoted_content': None,
#     'query': 'Doris',
#     'tweet_volume': 28603},
#    {'name': 'KoronaTahliyesinde Eşitlik',
#     'url': 'http://twitter.com/search?q=%22KoronaTahliyesinde+E%C5%9Fitlik%22',
#     'promoted_content': None,
#     'query': '%22KoronaTahliyesinde+E%C5%9Fitlik%22',
#     'tweet_volume': 141223},
#    {'name': 'Saat 22',
#     'url': 'http://twitter.com/search?q=%22Saat+22%22',
#     'promoted_content': None,
#     'query': '%22Saat+22%22',
#     'tweet_volume': 10853},
#    {'name': 'Vaticano',
#     'url': 'http://twitter.com/search?q=Vaticano',
#     'promoted_content': None,
#     'query': 'Vaticano',
#     'tweet_volume': 53287},
#    {'name': 'Gönüllü Karantina',
#     'url': 'http://twitter.com/search?q=%22G%C3%B6n%C3%BCll%C3%BC+Karantina%22',
#     'promoted_content': None,
#     'query': '%22G%C3%B6n%C3%BCll%C3%BC+Karantina%22',
#     'tweet_volume': None},
#    {'name': 'Massie',
#     'url': 'http://twitter.com/search?q=Massie',
#     'promoted_content': None,
#     'query': 'Massie',
#     'tweet_volume': 142013},
#    {'name': 'Imam',
#     'url': 'http://twitter.com/search?q=Imam',
#     'promoted_content': None,
#     'query': 'Imam',
#     'tweet_volume': 248345},
#    {'name': '#Rize',
#     'url': 'http://twitter.com/search?q=%23Rize',
#     'promoted_content': None,
#     'query': '%23Rize',
#     'tweet_volume': 37722},
#    {'name': '#คั่นกูEP6',
#     'url': 'http://twitter.com/search?q=%23%E0%B8%84%E0%B8%B1%E0%B9%88%E0%B8%99%E0%B8%81%E0%B8%B9EP6',
#     'promoted_content': None,
#     'query': '%23%E0%B8%84%E0%B8%B1%E0%B9%88%E0%B8%99%E0%B8%81%E0%B8%B9EP6',
#     'tweet_volume': 1356755},
#    {'name': '#virüsgeçince',
#     'url': 'http://twitter.com/search?q=%23vir%C3%BCsge%C3%A7ince',
#     'promoted_content': None,
#     'query': '%23vir%C3%BCsge%C3%A7ince',
#     'tweet_volume': None},
#    {'name': '#BlessedToHaveJackson',
#     'url': 'http://twitter.com/search?q=%23BlessedToHaveJackson',
#     'promoted_content': None,
#     'query': '%23BlessedToHaveJackson',
#     'tweet_volume': 463009},
#    {'name': '#CurfewKenya',
#     'url': 'http://twitter.com/search?q=%23CurfewKenya',
#     'promoted_content': None,
#     'query': '%23CurfewKenya',
#     'tweet_volume': 27101},
#    {'name': '#Mattarella',
#     'url': 'http://twitter.com/search?q=%23Mattarella',
#     'promoted_content': None,
#     'query': '%23Mattarella',
#     'tweet_volume': 13576},
#    {'name': '#yoperreosola',
#     'url': 'http://twitter.com/search?q=%23yoperreosola',
#     'promoted_content': None,
#     'query': '%23yoperreosola',
#     'tweet_volume': None},
#    {'name': '#بطوله_مساعد_الدوسري_للاعبين',
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D9%85%D8%B3%D8%A7%D8%B9%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B3%D8%B1%D9%8A_%D9%84%D9%84%D8%A7%D8%B9%D8%A8%D9%8A%D9%86',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D9%85%D8%B3%D8%A7%D8%B9%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B3%D8%B1%D9%8A_%D9%84%D9%84%D8%A7%D8%B9%D8%A8%D9%8A%D9%86',
#     'tweet_volume': 36027},
#    {'name': '#CumhurbaşkanıErdoğan',
#     'url': 'http://twitter.com/search?q=%23Cumhurba%C5%9Fkan%C4%B1Erdo%C4%9Fan',
#     'promoted_content': None,
#     'query': '%23Cumhurba%C5%9Fkan%C4%B1Erdo%C4%9Fan',
#     'tweet_volume': None},
#    {'name': '#WHYRUep10',
#     'url': 'http://twitter.com/search?q=%23WHYRUep10',
#     'promoted_content': None,
#     'query': '%23WHYRUep10',
#     'tweet_volume': 382295},
#    {'name': '#NOMORE_NTHROOM',
#     'url': 'http://twitter.com/search?q=%23NOMORE_NTHROOM',
#     'promoted_content': None,
#     'query': '%23NOMORE_NTHROOM',
#     'tweet_volume': 282517},
#    {'name': '#Yetersiz',
#     'url': 'http://twitter.com/search?q=%23Yetersiz',
#     'promoted_content': None,
#     'query': '%23Yetersiz',
#     'tweet_volume': 12609},
#    {'name': '#biawards',
#     'url': 'http://twitter.com/search?q=%23biawards',
#     'promoted_content': None,
#     'query': '%23biawards',
#     'tweet_volume': None},
#    {'name': '#1YearWithPersona',
#     'url': 'http://twitter.com/search?q=%231YearWithPersona',
#     'promoted_content': None,
#     'query': '%231YearWithPersona',
#     'tweet_volume': 66499},
#    {'name': '#suyasabunadokun',
#     'url': 'http://twitter.com/search?q=%23suyasabunadokun',
#     'promoted_content': None,
#     'query': '%23suyasabunadokun',
#     'tweet_volume': None},
#    {'name': '#PARANOIDBOOK',
#     'url': 'http://twitter.com/search?q=%23PARANOIDBOOK',
#     'promoted_content': None,
#     'query': '%23PARANOIDBOOK',
#     'tweet_volume': None},
#    {'name': '#PresidentCovik',
#     'url': 'http://twitter.com/search?q=%23PresidentCovik',
#     'promoted_content': None,
#     'query': '%23PresidentCovik',
#     'tweet_volume': 137106},
#    {'name': '#iyikivarsınkadınım',
#     'url': 'http://twitter.com/search?q=%23iyikivars%C4%B1nkad%C4%B1n%C4%B1m',
#     'promoted_content': None,
#     'query': '%23iyikivars%C4%B1nkad%C4%B1n%C4%B1m',
#     'tweet_volume': 75358},
#    {'name': '#StayAtHomeAndStaySafe',
#     'url': 'http://twitter.com/search?q=%23StayAtHomeAndStaySafe',
#     'promoted_content': None,
#     'query': '%23StayAtHomeAndStaySafe',
#     'tweet_volume': 13945},
#    {'name': '#ImpeachmentDeDoria',
#     'url': 'http://twitter.com/search?q=%23ImpeachmentDeDoria',
#     'promoted_content': None,
#     'query': '%23ImpeachmentDeDoria',
#     'tweet_volume': 37622},
#    {'name': '#dwdd',
#     'url': 'http://twitter.com/search?q=%23dwdd',
#     'promoted_content': None,
#     'query': '%23dwdd',
#     'tweet_volume': None},
#    {'name': '#UnEndorseBiden',
#     'url': 'http://twitter.com/search?q=%23UnEndorseBiden',
#     'promoted_content': None,
#     'query': '%23UnEndorseBiden',
#     'tweet_volume': 17145},
#    {'name': '#منظمه_الصحه_تشيد_بالسعوديه',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D9%86%D8%B8%D9%85%D9%87_%D8%A7%D9%84%D8%B5%D8%AD%D9%87_%D8%AA%D8%B4%D9%8A%D8%AF_%D8%A8%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%85%D9%86%D8%B8%D9%85%D9%87_%D8%A7%D9%84%D8%B5%D8%AD%D9%87_%D8%AA%D8%B4%D9%8A%D8%AF_%D8%A8%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'tweet_volume': None},
#    {'name': '#علوش_القحطاني',
#     'url': 'http://twitter.com/search?q=%23%D8%B9%D9%84%D9%88%D8%B4_%D8%A7%D9%84%D9%82%D8%AD%D8%B7%D8%A7%D9%86%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D8%B9%D9%84%D9%88%D8%B4_%D8%A7%D9%84%D9%82%D8%AD%D8%B7%D8%A7%D9%86%D9%8A',
#     'tweet_volume': 31467},
#    {'name': '#CuandoEstoSeAcabe',
#     'url': 'http://twitter.com/search?q=%23CuandoEstoSeAcabe',
#     'promoted_content': None,
#     'query': '%23CuandoEstoSeAcabe',
#     'tweet_volume': 15429},
#    {'name': '#FridayMotivation',
#     'url': 'http://twitter.com/search?q=%23FridayMotivation',
#     'promoted_content': None,
#     'query': '%23FridayMotivation',
#     'tweet_volume': 41830},
#    {'name': '#BetsmovedaKal',
#     'url': 'http://twitter.com/search?q=%23BetsmovedaKal',
#     'promoted_content': None,
#     'query': '%23BetsmovedaKal',
#     'tweet_volume': None},
#    {'name': '#TheQueenMzanzi',
#     'url': 'http://twitter.com/search?q=%23TheQueenMzanzi',
#     'promoted_content': None,
#     'query': '%23TheQueenMzanzi',
#     'tweet_volume': None},
#    {'name': '#FelizViernesAtodos',
#     'url': 'http://twitter.com/search?q=%23FelizViernesAtodos',
#     'promoted_content': None,
#     'query': '%23FelizViernesAtodos',
#     'tweet_volume': 17352},
#    {'name': '#SağlığımızlaOynamaİBB',
#     'url': 'http://twitter.com/search?q=%23Sa%C4%9Fl%C4%B1%C4%9F%C4%B1m%C4%B1zlaOynama%C4%B0BB',
#     'promoted_content': None,
#     'query': '%23Sa%C4%9Fl%C4%B1%C4%9F%C4%B1m%C4%B1zlaOynama%C4%B0BB',
#     'tweet_volume': 21229},
#    {'name': '#بو_نحالين',
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D9%88_%D9%86%D8%AD%D8%A7%D9%84%D9%8A%D9%86',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D9%88_%D9%86%D8%AD%D8%A7%D9%84%D9%8A%D9%86',
#     'tweet_volume': 11749},
#    {'name': '#لاتخرجون_الا_للضروره',
#     'url': 'http://twitter.com/search?q=%23%D9%84%D8%A7%D8%AA%D8%AE%D8%B1%D8%AC%D9%88%D9%86_%D8%A7%D9%84%D8%A7_%D9%84%D9%84%D8%B6%D8%B1%D9%88%D8%B1%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%84%D8%A7%D8%AA%D8%AE%D8%B1%D8%AC%D9%88%D9%86_%D8%A7%D9%84%D8%A7_%D9%84%D9%84%D8%B6%D8%B1%D9%88%D8%B1%D9%87',
#     'tweet_volume': 14100},
#    {'name': '#اقل_واجب_البيت_الرومانسي',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%82%D9%84_%D9%88%D8%A7%D8%AC%D8%A8_%D8%A7%D9%84%D8%A8%D9%8A%D8%AA_%D8%A7%D9%84%D8%B1%D9%88%D9%85%D8%A7%D9%86%D8%B3%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%82%D9%84_%D9%88%D8%A7%D8%AC%D8%A8_%D8%A7%D9%84%D8%A8%D9%8A%D8%AA_%D8%A7%D9%84%D8%B1%D9%88%D9%85%D8%A7%D9%86%D8%B3%D9%8A',
#     'tweet_volume': None},
#    {'name': '#NickiDay',
#     'url': 'http://twitter.com/search?q=%23NickiDay',
#     'promoted_content': None,
#     'query': '%23NickiDay',
#     'tweet_volume': 15996},
#    {'name': '#حماس_شريكه_الحوثي',
#     'url': 'http://twitter.com/search?q=%23%D8%AD%D9%85%D8%A7%D8%B3_%D8%B4%D8%B1%D9%8A%D9%83%D9%87_%D8%A7%D9%84%D8%AD%D9%88%D8%AB%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D8%AD%D9%85%D8%A7%D8%B3_%D8%B4%D8%B1%D9%8A%D9%83%D9%87_%D8%A7%D9%84%D8%AD%D9%88%D8%AB%D9%8A',
#     'tweet_volume': None},
#    {'name': '#NeumoniaAtipica',
#     'url': 'http://twitter.com/search?q=%23NeumoniaAtipica',
#     'promoted_content': None,
#     'query': '%23NeumoniaAtipica',
#     'tweet_volume': 19389},
#    {'name': '#VibePayFriday',
#     'url': 'http://twitter.com/search?q=%23VibePayFriday',
#     'promoted_content': None,
#     'query': '%23VibePayFriday',
#     'tweet_volume': None}],
#   'as_of': '2020-03-27T20:11:46Z',
#   'created_at': '2020-03-27T20:05:32Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#CoronaLockdown', 'url': 'http://twitter.com/search?q=%23CoronaLockdown', 'promoted_content': None, 'query': '%23CoronaLockdown', 'tweet_volume': 231154}, {'name': '#OpeningDayAtHome', 'url': 'http://twitter.com/search?q=%23OpeningDayAtHome', 'promoted_content': None, 'query': '%23OpeningDayAtHome', 'tweet_volume': 98637}, {'name': '#payitforwardlive', 'url': 'http://twitter.com/search?q=%23payitforwardlive', 'promoted_content': None, 'query': '%23payitforwardlive', 'tweet_volume': 39321}, {'name': '#KickIt1stwin', 'url': 'http://twitter.com/search?q=%23KickIt1stwin', 'promoted_content': None, 'query': '%23KickIt1stwin', 'tweet_volume': 3292934}, {'name': 'Tiger King', 'url': 'http://twitter.com/search?q=%22Tiger+King%22', 'promoted_content': None, 'query': '%22Tiger+King%22', 'tweet_volume': 46582}, {'name': '#FutureNostalgia', 'url': 'http://twitter.com/search?q=%23FutureNostalgia', 'promoted_content': None, 'query': '%23FutureNostalgia', 'tweet_volume': 127139}, {'name': 'Doris', 'url': 'http://twitter.com/search?q=Doris', 'promoted_content': None, 'query': 'Doris', 'tweet_volume': 28603}, {'name': 'Massie', 'url': 'http://twitter.com/search?q=Massie', 'promoted_content': None, 'query': 'Massie', 'tweet_volume': 142013}, {'name': 'Yo Perreo Sola', 'url': 'http://twitter.com/search?q=%22Yo+Perreo+Sola%22', 'promoted_content': None, 'query': '%22Yo+Perreo+Sola%22', 'tweet_volume': 10484}, {'name': 'Reggie Bush', 'url': 'http://twitter.com/search?q=%22Reggie+Bush%22', 'promoted_content': None, 'query': '%22Reggie+Bush%22', 'tweet_volume': None}, {'name': 'John Kerry', 'url': 'http://twitter.com/search?q=%22John+Kerry%22', 'promoted_content': None, 'query': '%22John+Kerry%22', 'tweet_volume': 24212}, {'name': 'Lordstown', 'url': 'http://twitter.com/search?q=Lordstown', 'promoted_content': None, 'query': 'Lordstown', 'tweet_volume': 45029}, {'name': 'Octane', 'url': 'http://twitter.com/search?q=Octane', 'promoted_content': None, 'query': 'Octane', 'tweet_volume': None}, {'name': 'Ricky Williams', 'url': 'http://twitter.com/search?q=%22Ricky+Williams%22', 'promoted_content': None, 'query': '%22Ricky+Williams%22', 'tweet_volume': None}, {'name': 'Bob Dylan', 'url': 'http://twitter.com/search?q=%22Bob+Dylan%22', 'promoted_content': None, 'query': '%22Bob+Dylan%22', 'tweet_volume': 39612}, {'name': 'Greg the Leg', 'url': 'http://twitter.com/search?q=%22Greg+the+Leg%22', 'promoted_content': None, 'query': '%22Greg+the+Leg%22', 'tweet_volume': None}, {'name': 'Invoke P', 'url': 'http://twitter.com/search?q=%22Invoke+P%22', 'promoted_content': None, 'query': '%22Invoke+P%22', 'tweet_volume': 41689}, {'name': 'Johnny Juzang', 'url': 'http://twitter.com/search?q=%22Johnny+Juzang%22', 'promoted_content': None, 'query': '%22Johnny+Juzang%22', 'tweet_volume': None}, {'name': 'General Motors', 'url': 'http://twitter.com/search?q=%22General+Motors%22', 'promoted_content': None, 'query': '%22General+Motors%22', 'tweet_volume': 67861}, {'name': 'Bloodhound', 'url': 'http://twitter.com/search?q=Bloodhound', 'promoted_content': None, 'query': 'Bloodhound', 'tweet_volume': None}, {'name': 'Lifeline', 'url': 'http://twitter.com/search?q=Lifeline', 'promoted_content': None, 'query': 'Lifeline', 'tweet_volume': None}, {'name': 'Wraith', 'url': 'http://twitter.com/search?q=Wraith', 'promoted_content': None, 'query': 'Wraith', 'tweet_volume': None}, {'name': 'Wattson', 'url': 'http://twitter.com/search?q=Wattson', 'promoted_content': None, 'query': 'Wattson', 'tweet_volume': None}, {'name': 'Dear April', 'url': 'http://twitter.com/search?q=%22Dear+April%22', 'promoted_content': None, 'query': '%22Dear+April%22', 'tweet_volume': None}, {'name': 'Hoda', 'url': 'http://twitter.com/search?q=Hoda', 'promoted_content': None, 'query': 'Hoda', 'tweet_volume': 18022}, {'name': 'Pathfinder', 'url': 'http://twitter.com/search?q=Pathfinder', 'promoted_content': None, 'query': 'Pathfinder', 'tweet_volume': None}, {'name': 'Kirk Herbstreit', 'url': 'http: ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Doris",
#     "url": "http://twitter.com/search?q=Doris",
#     "promoted_content": null,
#     "query": "Doris",
#     "tweet_volume": 29158
#    },
#    {
#     "name": "#CoronaLockdown",
#     "url": "http://twitter.com/search?q=%23CoronaLockdown",
#     "promoted_content": null,
#     "query": "%23CoronaLockdown",
#     "tweet_volume": 232846
#    },
#    {
#     "name": "#freecodefridaycontest",
#     "url": "http://twitter.com/search?q=%23freecodefridaycontest",
#     "promoted_content": null,
#     "query": "%23freecodefridaycontest",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UnEndorseBiden",
#     "url": "http://twitter.com/search?q=%23UnEndorseBiden",
#     "promoted_content": null,
#     "query": "%23UnEndorseBiden",
#     "tweet_volume": 17969
#    },
#    {
#     "name": "#PARANOIDBOOK",
#     "url": "http://twitter.com/search?q=%23PARANOIDBOOK",
#     "promoted_content": null,
#     "query": "%23PARANOIDBOOK",
#     "tweet_volume": null
#    },
#    {
#     "name": "Yo Perreo Sola",
#     "url": "http://twitter.com/search?q=%22Yo+Perreo+Sola%22",
#     "promoted_content": null,
#     "query": "%22Yo+Perreo+Sola%22",
#     "tweet_volume": 11942
#    },
#    {
#     "name": "Massie",
#     "url": "http://twitter.com/search?q=Massie",
#     "promoted_content": null,
#     "query": "Massie",
#     "tweet_volume": 143006
#    },
#    {
#     "name": "#FridayMotivation",
#     "url": "http://twitter.com/search?q=%23FridayMotivation",
#     "promoted_content": null,
#     "query": "%23FridayMotivation",
#     "tweet_volume": 42088
#    },
#    {
#     "name": "Reggie Bush",
#     "url": "http://twitter.com/search?q=%22Reggie+Bush%22",
#     "promoted_content": null,
#     "query": "%22Reggie+Bush%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "John Kerry",
#     "url": "http://twitter.com/search?q=%22John+Kerry%22",
#     "promoted_content": null,
#     "query": "%22John+Kerry%22",
#     "tweet_volume": 24368
#    },
#    {
#     "name": "Lordstown",
#     "url": "http://twitter.com/search?q=Lordstown",
#     "promoted_content": null,
#     "query": "Lordstown",
#     "tweet_volume": 45470
#    },
#    {
#     "name": "Greg the Leg",
#     "url": "http://twitter.com/search?q=%22Greg+the+Leg%22",
#     "promoted_content": null,
#     "query": "%22Greg+the+Leg%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Octane",
#     "url": "http://twitter.com/search?q=Octane",
#     "promoted_content": null,
#     "query": "Octane",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ricky Williams",
#     "url": "http://twitter.com/search?q=%22Ricky+Williams%22",
#     "promoted_content": null,
#     "query": "%22Ricky+Williams%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bob Dylan",
#     "url": "http://twitter.com/search?q=%22Bob+Dylan%22",
#     "promoted_content": null,
#     "query": "%22Bob+Dylan%22",
#     "tweet_volume": 39785
#    },
#    {
#     "name": "General Motors",
#     "url": "http://twitter.com/search?q=%22General+Motors%22",
#     "promoted_content": null,
#     "query": "%22General+Motors%22",
#     "tweet_volume": 69363
#    },
#    {
#     "name": "Johnny Juzang",
#     "url": "http://twitter.com/search?q=%22Johnny+Juzang%22",
#     "promoted_content": null,
#     "query": "%22Johnny+Juzang%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Invoke P",
#     "url": "http://twitter.com/search?q=%22Invoke+P%22",
#     "promoted_content": null,
#     "query": "%22Invoke+P%22",
#     "tweet_volume": 41925
#    },
#    {
#     "name": "Bloodhound",
#     "url": "http://twitter.com/search?q=Bloodhound",
#     "promoted_content": null,
#     "query": "Bloodhound",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lifeline",
#     "url": "http://twitter.com/search?q=Lifeline",
#     "promoted_content": null,
#     "query": "Lifeline",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wraith",
#     "url": "http://twitter.com/search?q=Wraith",
#     "promoted_content": null,
#     "query": "Wraith",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pathfinder",
#     "url": "http://twitter.com/search?q=Pathfinder",
#     "promoted_content": null,
#     "query": "Pathfinder",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hoda",
#     "url": "http://twitter.com/search?q=Hoda",
#     "promoted_content": null,
#     "query": "Hoda",
#     "tweet_volume": 18082
#    },
#    {
#     "name": "Wattson",
#     "url": "http://twitter.com/search?q=Wattson",
#     "promoted_content": null,
#     "query": "Wattson",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dear April",
#     "url": "http://twitter.com/search?q=%22Dear+April%22",
#     "promoted_content": null,
#     "query": "%22Dear+April%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Forbath",
#     "url": "http://twitter.com/search?q=Forbath",
#     "promoted_content": null,
#     "query": "Forbath",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kirk Herbstreit",
#     "url": "http://twitter.com/search?q=%22Kirk+Herbstreit%22",
#     "promoted_content": null,
#     "query": "%22Kirk+Herbstreit%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Earl Campbell",
#     "url": "http://twitter.com/search?q=%22Earl+Campbell%22",
#     "promoted_content": null,
#     "query": "%22Earl+Campbell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#rentrelief",
#     "url": "http://twitter.com/search?q=%23rentrelief",
#     "promoted_content": null,
#     "query": "%23rentrelief",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NickiDay",
#     "url": "http://twitter.com/search?q=%23NickiDay",
#     "promoted_content": null,
#     "query": "%23NickiDay",
#     "tweet_volume": 16550
#    },
#    {
#     "name": "#NationalJoeDay",
#     "url": "http://twitter.com/search?q=%23NationalJoeDay",
#     "promoted_content": null,
#     "query": "%23NationalJoeDay",
#     "tweet_volume": 10060
#    },
#    {
#     "name": "#BlessedToHaveJackson",
#     "url": "http://twitter.com/search?q=%23BlessedToHaveJackson",
#     "promoted_content": null,
#     "query": "%23BlessedToHaveJackson",
#     "tweet_volume": 464413
#    },
#    {
#     "name": "#1YearWithPersona",
#     "url": "http://twitter.com/search?q=%231YearWithPersona",
#     "promoted_content": null,
#     "query": "%231YearWithPersona",
#     "tweet_volume": 66887
#    },
#    {
#     "name": "#FlashbackFriday",
#     "url": "http://twitter.com/search?q=%23FlashbackFriday",
#     "promoted_content": null,
#     "query": "%23FlashbackFriday",
#     "tweet_volume": 13782
#    },
#    {
#     "name": "#WorldTheatreDay",
#     "url": "http://twitter.com/search?q=%23WorldTheatreDay",
#     "promoted_content": null,
#     "query": "%23WorldTheatreDay",
#     "tweet_volume": 38110
#    },
#    {
#     "name": "#InMyAloneTime",
#     "url": "http://twitter.com/search?q=%23InMyAloneTime",
#     "promoted_content": null,
#     "query": "%23InMyAloneTime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MasksNow",
#     "url": "http://twitter.com/search?q=%23MasksNow",
#     "promoted_content": null,
#     "query": "%23MasksNow",
#     "tweet_volume": 63798
#    },
#    {
#     "name": "#FursuitFriday",
#     "url": "http://twitter.com/search?q=%23FursuitFriday",
#     "promoted_content": null,
#     "query": "%23FursuitFriday",
#     "tweet_volume": 11126
#    },
#    {
#     "name": "#SELDay",
#     "url": "http://twitter.com/search?q=%23SELDay",
#     "promoted_content": null,
#     "query": "%23SELDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ScienceFight",
#     "url": "http://twitter.com/search?q=%23ScienceFight",
#     "promoted_content": null,
#     "query": "%23ScienceFight",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Ozarkseason3",
#     "url": "http://twitter.com/search?q=%23Ozarkseason3",
#     "promoted_content": null,
#     "query": "%23Ozarkseason3",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ClapBecauseWeCare",
#     "url": "http://twitter.com/search?q=%23ClapBecauseWeCare",
#     "promoted_content": null,
#     "query": "%23ClapBecauseWeCare",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AtelierRyza",
#     "url": "http://twitter.com/search?q=%23AtelierRyza",
#     "promoted_content": null,
#     "query": "%23AtelierRyza",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NewMusicFriday",
#     "url": "http://twitter.com/search?q=%23NewMusicFriday",
#     "promoted_content": null,
#     "query": "%23NewMusicFriday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UrbietOrbi",
#     "url": "http://twitter.com/search?q=%23UrbietOrbi",
#     "promoted_content": null,
#     "query": "%23UrbietOrbi",
#     "tweet_volume": 27243
#    },
#    {
#     "name": "#CNWatchParty",
#     "url": "http://twitter.com/search?q=%23CNWatchParty",
#     "promoted_content": null,
#     "query": "%23CNWatchParty",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Fight4HER",
#     "url": "http://twitter.com/search?q=%23Fight4HER",
#     "promoted_content": null,
#     "query": "%23Fight4HER",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StayAtHomeAndStaySafe",
#     "url": "http://twitter.com/search?q=%23StayAtHomeAndStaySafe",
#     "promoted_content": null,
#     "query": "%23StayAtHomeAndStaySafe",
#     "tweet_volume": 14119
#    },
#    {
#     "name": "#DeborahBirx",
#     "url": "http://twitter.com/search?q=%23DeborahBirx",
#     "promoted_content": null,
#     "query": "%23DeborahBirx",
#     "tweet_volume": 21555
#    },
#    {
#     "name": "#Give4COVIDRelief",
#     "url": "http://twitter.com/search?q=%23Give4COVIDRelief",
#     "promoted_content": null,
#     "query": "%23Give4COVIDRelief",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-03-27T20:11:47Z",
#   "created_at": "2020-03-27T20:10:32Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #بطوله_مساعد_الدوسري_للاعبين,#PARANOIDBOOK,#حماس_شريكه_الحوثي,#بو_نحالين,#StayAtHomeAndStaySafe,Imam,#dwdd,KoronaTahliyesinde Eşitlik,#iyikivarsınkadınım,#PresidentCovik,Papa Francisco,Saat 22,#FicaPrior,#LockdownHouseParty,#VibePayFriday,#คั่นกูEP6,#TheQueenMzanzi,#FelizViernesAtodos,#FridayMotivation,#biawards,#Yetersiz,Doris,#CoronaLockdown,#ImpeachmentDeDoria,#TayyipErdoganNerede,Massie,#suyasabunadokun,#CurfewKenya,Gönüllü Karantina,#NOMORE_NTHROOM,#منظمه_الصحه_تشيد_بالسعوديه,#BlessedToHaveJackson,#اقل_واجب_البيت_الرومانسي,#CuandoEstoSeAcabe,#vaka5698,#CumhurbaşkanıErdoğan,#لاتخرجون_الا_للضروره,#علوش_القحطاني,#BetsmovedaKal,#Rize,Vaticano,#UnEndorseBiden,#1YearWithPersona,#NeumoniaAtipica,#Mattarella,#WHYRUep10,#SağlığımızlaOynamaİBB,#NickiDay,#yoperreosola,#virüsgeçince
# ('----------', 'us')
# #PARANOIDBOOK,#FlashbackFriday,#StayAtHomeAndStaySafe,#WorldTheatreDay,#ClapBecauseWeCare,Ricky Williams,#NationalJoeDay,Bloodhound,Earl Campbell,#CNWatchParty,Lordstown,#rentrelief,Invoke P,Forbath,#UrbietOrbi,#AtelierRyza,Hoda,#freecodefridaycontest,Greg the Leg,#FridayMotivation,Pathfinder,#InMyAloneTime,Johnny Juzang,Lifeline,#Ozarkseason3,#NewMusicFriday,Doris,#Fight4HER,#CoronaLockdown,Wattson,Massie,#MasksNow,John Kerry,Wraith,#BlessedToHaveJackson,Dear April,Yo Perreo Sola,#DeborahBirx,General Motors,Kirk Herbstreit,#ScienceFight,#UnEndorseBiden,Bob Dylan,#1YearWithPersona,#FursuitFriday,Reggie Bush,#SELDay,#Give4COVIDRelief,#NickiDay,Octane
# ('----------', 'san diego')
# #OpeningDayAtHome,#PARANOIDBOOK,Tiger King,#StayAtHomeAndStaySafe,#WorldTheatreDay,#payitforwardlive,Ricky Williams,#ClapBecauseWeCare,#NationalJoeDay,Bloodhound,#CNWatchParty,Lordstown,#rentrelief,Invoke P,#AtelierRyza,#FridayVibes,Hoda,Greg the Leg,Pathfinder,#InMyAloneTime,Johnny Juzang,Lifeline,#Ozarkseason3,Doris,#Fight4HER,#CoronaLockdown,Wattson,Massie,#MasksNow,John Kerry,Wraith,#BlessedToHaveJackson,#KickIt1stwin,#FutureNostalgia,Dear April,Yo Perreo Sola,#DeborahBirx,General Motors,Kirk Herbstreit,#ScienceFight,#UnEndorseBiden,Bob Dylan,#1YearWithPersona,#FursuitFriday,Reggie Bush,#SELDay,#Give4COVIDRelief,#NickiDay,Octane,#KillingEve

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#PARANOIDBOOK', 'Doris', '#StayAtHomeAndStaySafe', '#CoronaLockdown', '#UnEndorseBiden', '#1YearWithPersona', 'Massie', '#BlessedToHaveJackson', '#FridayMotivation', '#NickiDay'}
# ('==========', 'intersection of us and san-diego')
# {'#PARANOIDBOOK', '#StayAtHomeAndStaySafe', '#WorldTheatreDay', '#ClapBecauseWeCare', 'Ricky Williams', '#NationalJoeDay', 'Bloodhound', 'Octane', '#CNWatchParty', 'Lordstown', '#rentrelief', 'Invoke P', '#AtelierRyza', 'Hoda', 'Greg the Leg', 'Pathfinder', '#InMyAloneTime', 'Johnny Juzang', 'Lifeline', '#Ozarkseason3', 'Doris', '#Fight4HER', '#CoronaLockdown', 'Wattson', 'Massie', '#MasksNow', 'John Kerry', 'Wraith', '#BlessedToHaveJackson', 'Dear April', 'Yo Perreo Sola', '#DeborahBirx', 'General Motors', 'Kirk Herbstreit', '#UnEndorseBiden', 'Bob Dylan', '#1YearWithPersona', '#FursuitFriday', 'Reggie Bush', '#SELDay', '#Give4COVIDRelief', '#NickiDay', '#ScienceFight'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Fri Mar 27 17:56:55 +0000 2020', 'id': 1243597885624680449, 'id_str': '1243597885624680449', 'text': 'RT @MTVAwards: Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards? 💋\n\nVote,…', 'truncated': False, 'entities': {'hashtags': [{'text': 'CharlesMelton', 'indices': [28, 42]}, {'text': 'MTVAwards', 'indices': [119, 129]}], 'symbols': [], 'user_mentions': [{'screen_name': 'MTVAwards', 'name': 'Movie & TV Awards', 'id': 834116685577740290, 'id_str': '834116685577740290', 'indices': [3, 13]}, {'screen_name': 'CamilaMendes', 'name': 'Camila Mendes', 'id': 709540733456224257, 'id_str': '709540733456224257', 'indices': [47, 60]}, {'screen_name': 'CW_Riverdale', 'name': 'Riverdale', 'id': 4918738512, 'id_str': '4918738512', 'indices': [93, 106]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1068982710159532033, 'id_str': '1068982710159532033', 'name': 'maddie m', 'screen_name': 'maddiem10125980', 'location': 'Middleburg Heights, OH', 'description': 'DIY & Home', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 191, 'friends_count': 1615, 'listed_count': 0, 'created_at': 'Sat Dec 01 21:38:33 +0000 2018', 'favourites_count': 64328, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 96865, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1068983786694684672/Iv--znpk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068983786694684672/Iv--znpk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068982710159532033/1556752519', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 21 20:34:10 +0000 2019', 'id': 1130934834539442176, 'id_str': '1130934834539442176', 'text': 'Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards?… https://t.co/Niuf7VBmJL', 'truncated': True, 'entities': {'hashtags': [{'text': 'CharlesMelton', 'indices': [13, 27]}, {'text': 'MTVAwards', 'indices': [104, 114]}], 'symbols': [], 'user_mentions': [{'screen_name': 'CamilaMendes', 'name': 'Camila Mendes', 'id': 709540733456224257, 'id_str': '709540733456224257', 'indices': [32, 45]}, {'screen_name': 'CW_Riverdale', 'name': 'Riverdale', 'id': 4918738512, 'id_str': '4918738512', 'indices': [78, 91]}], 'urls': [{'url': 'https://t.co/Niuf7VBmJL', 'expanded_url': 'https://twitter.com/i/web/status/1130934834539442176', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 834116685577740290, 'id_str': '834116685577740290', 'name': 'Movie & TV Awards', 'screen_nam ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 23

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @MTVAwards: Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards? 💋\n\nVote,…',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @MTV: 🚨 #DolanTwins alert 🚨 Hang with @graysondolan and @ethandolan at the #MTVAwards tonight at 9/8c! 😘 https://t.co/2pqo3imKGr',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'Simply Gentle.🐅\n\n📷 sumisevent  Photos.\n\n#artist  #musician  #music #buzz #night #trends #style #stylist #shop… https://t.co/Q9KPU7IDGV',
#  "RT @MTV: We love two (2) red carpet angels!! ✨ @VanessaMarano @lauramarano \n\nDon't miss any of the glam at this year's #MTVAwards on Monday…",
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @lenascorpio20: Love is a touch of friendship and a handful of dreams. Such a happy moment for Becky and she deserves every bit of this…',
#  'RT @lenascorpio20: Love is a touch of friendship and a handful of dreams. Such a happy moment for Becky and she deserves every bit of this…',
#  'RT @lenascorpio20: Love is a touch of friendship and a handful of dreams. Such a happy moment for Becky and she deserves every bit of this…',
#  'RT @MTVLA: EL DÚO MÁS TIERNO DE TODOS LOS TIEMPOS! @RealHughJackman &amp; Dafne Keen #MTVAwards 🙌🏼 https://t.co/3wGzclQYAd',
#  'RT @MTV: Congrats to my bb @madelainepetsch on winning Best Scene Stealer at the #MTVAwards. https://t.co/FYvWst0iI7',
#  'RT @RuPaulsDragRace: Finish her! 👊 Fatality! ☠️ Katya wins! 🏆\n\n@AlyssaEdwards_1, @katya_zamo, and @trixiemattel had an absolute kiki watchi…',
#  'RT @MTVAwards: Happiest of birthdays to the host of the 2000 #MTVAwards, #SarahJessicaParker 🎉🎂 https://t.co/Sb6RG94qXA',
#  'Happiest of birthdays to the host of the 2000 #MTVAwards, #SarahJessicaParker 🎉🎂 https://t.co/Sb6RG94qXA',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: @OnMyBlock @TheJasonGenao @JessMarieGarcia "I WANNA WIN THE DANCE COMPETITION!" \n\nDo you also wanna win Best Musical Moment?…',
#  'RT @MTVAwards: @OnMyBlock @TheJasonGenao @JessMarieGarcia "I WANNA WIN THE DANCE COMPETITION!" \n\nDo you also wanna win Best Musical Moment?…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  "RT @MTVteenwolf: Here's to hoping that the weather at this Monday's #MTVAwards isn't as London-like as it was for @daniel_sharman in 2013…",
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @jaedenbrasil: 🎥| Jaeden, Finn e Wyatt na noite de ontem depois do #MTVAwards (via Instagram Stories do Jack). https://t.co/BktuDl4cLc',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  'RT @MTVAwards: The @Stranger_Things cast reveal what you can expect from Season 3 backstage at #MTVAwards 👀 https://t.co/BnrhhDOSQz',
#  'RT @MTVAwards: That time when two iconic casts came together! 😍\n\nThe @13ReasonsWhy cast presented the @Stranger_Things cast with their awar…',
#  'RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet 💰@JessMarieGarcia @TheJasonGenao 💋🔥\n\nTune in to the #MTVAwards Monda…',
#  '@NICKIMINAJ  #mtvawards https://t.co/z9xImo2igD']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri Mar 27 17:56:55 +0000 2020",
#  "id": 1243597885624680449,
#  "id_str": "1243597885624680449",
#  "text": "RT @MTVAwards: Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards? \ud83d\udc8b\n\nVote,\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "CharlesMelton",
#     "indices": [
#      28,
#      42
#     ]
#    },
#    {
#     "text": "MTVAwards",
#     "indices": [
#      119,
#      129
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MTVAwards",
#     "name": "Movie & TV Awards",
#     "id": 834116685577740290,
#     "id_str": "834116685577740290",
#     "indices": [
#      3,
#      13
#     ]
#    },
#    {
#     "screen_name": "CamilaMendes",
#     "name": "Camila Mendes",
#     "id": 709540733456224257,
#     "id_str": "709540733456224257",
#     "indices": [
#      47,
#      60
#     ]
#    },
#    {
#     "screen_name": "CW_Riverdale",
#     "name": "Riverdale",
#     "id": 4918738512,
#     "id_str": "4918738512",
#     "indices": [
#      93,
#      106
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1068982710159532033,
#   "id_str": "1068982710159532033",
#   "name": "maddie m",
#   "screen_name": "maddiem10125980",
#   "location": "Middleburg Heights, OH",
#   "description": "DIY & Home",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 191,
#   "friends_count": 1615,
#   "listed_count": 0,
#   "created_at": "Sat Dec 01 21:38:33 +0000 2018",
#   "favourites_count": 64328,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 96865,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1068983786694684672/Iv--znpk_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1068983786694684672/Iv--znpk_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1068982710159532033/1556752519",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue May 21 20:34:10 +0000 2019",
#   "id": 1130934834539442176,
#   "id_str": "1130934834539442176",
#   "text": "Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards?\u2026 https://t.co/Niuf7VBmJL",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "CharlesMelton",
#      "indices": [
#       13,
#       27
#      ]
#     },
#     {
#      "text": "MTVAwards",
#      "indices": [
#       104,
#       114
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "CamilaMendes",
#      "name": "Camila Mendes",
#      "id": 709540733456224257,
#      "id_str": "709540733456224257",
#      "indices": [
#       32,
#       45
#      ]
#     },
#     {
#      "screen_name": "CW_Riverdale",
#      "name": "Riverdale",
#      "id": 4918738512,
#      "id_str": "4918738512",
#      "indices": [
#       78,
#       91
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/Niuf7VBmJL",
#      "expanded_url": "https://twitter.com/i/web/status/1130934834539442176",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 834116685577740290,
#    "id_str": "834116685577740290",
#    "name": "Movie & TV Awards",
#    "screen_name": "MTVAwards",
#    "location": "Los Angeles, CA",
#    "description": "I'll bring the popcorn. \ud83c\udf7f #MTVAwards",
#    "url": "https://t.co/WDnzRI0LPX",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/WDnzRI0LPX",
#        "expanded_url": "http://mtvawards.mtv.com",
#        "display_url": "mtvawards.mtv.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 35234,
#    "friends_count": 10365,
#    "listed_count": 185,
#    "created_at": "Tue Feb 21 19:04:49 +0000 2017",
#    "favourites_count": 4689,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": true,
#    "statuses_count": 4319,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/834116685577740290/1574179555",
#    "profile_link_color": "D4AF37",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 35,
#   "favorite_count": 269,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 35,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 35
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @MTVAwards: Did you hear #CharlesMelton and @CamilaMendes are nominated for Best Kiss for @CW_Riverdale at the 2019 #MTVAwards? \ud83d\udc8b\n\nVote,\u2026",
#  "RT @dunevillenuve: chloe and halle are angels beyonc\u00e9 really did bless them #mtvawards  https://t.co/y2fDHMj3rs",
#  "RT @MTV: \ud83d\udea8 #DolanTwins alert \ud83d\udea8 Hang with @graysondolan and @ethandolan at the #MTVAwards tonight at 9/8c! \ud83d\ude18 https://t.co/2pqo3imKGr",
#  "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "RT @MTVAwards: The @OnMyBlock homies truly dominated on the red carpet \ud83d\udcb0@JessMarieGarcia @TheJasonGenao \ud83d\udc8b\ud83d\udd25\n\nTune in to the #MTVAwards Monda\u2026"
# ]
# [
#  "MTVAwards",
#  "CamilaMendes",
#  "CW_Riverdale",
#  "dunevillenuve",
#  "MTV"
# ]
# [
#  "CharlesMelton",
#  "MTVAwards",
#  "mtvawards",
#  "DolanTwins",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@MTVAwards:",
#  "Did",
#  "you",
#  "hear"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 20), ('the', 19), ('at', 11), ('#MTVAwards', 10), ('of', 10), ('and', 8), ('@MTVAwards:', 7), ('to', 6), ('@MTV:', 5), ('for', 4)]
#
# [('MTVAwards', 7), ('MTV', 5), ('OnMyBlock', 2), ('JessMarieGarcia', 2), ('TheJasonGenao', 2), ('Stranger_Things', 2), ('CamilaMendes', 1), ('CW_Riverdale', 1), ('dunevillenuve', 1), ('GraysonDolan', 1)]
#
# [('MTVAwards', 15), ('mtvawards', 3), ('SarahJessicaParker', 2), ('CharlesMelton', 1), ('DolanTwins', 1), ('ToyotaCHR', 1), ('artist', 1), ('musician', 1), ('music', 1), ('buzz', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     20
# the                  |     19
# at                   |     11
# #MTVAwards           |     10
# of                   |     10
# and                  |      8
# @MTVAwards:          |      7
# to                   |      6
# @MTV:                |      5
# for                  |      4
#
#     Screen Name      | Count
# ****************************************
# MTVAwards            |      7
# MTV                  |      5
# OnMyBlock            |      2
# JessMarieGarcia      |      2
# TheJasonGenao        |      2
# Stranger_Things      |      2
# CamilaMendes         |      1
# CW_Riverdale         |      1
# dunevillenuve        |      1
# GraysonDolan         |      1
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     15
# mtvawards            |      3
# SarahJessicaParker   |      2
# CharlesMelton        |      1
# DolanTwins           |      1
# ToyotaCHR            |      1
# artist               |      1
# musician             |      1
# music                |      1
# buzz                 |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  4559   |       MTV       | RT @MTV: My queens @chloexhalle slayed their perfo
#         |                 | rmance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9
#  3541   |   tylergposey   | RT @tylergposey: last year I wore a onesie, this y
#         |                 | ear who knows? tomorrow's the #mtvawards and I'm t
#         |                 | eaming up w/#ToyotaCHR to make some mis…
#  3308   |  dunevillenuve  | RT @dunevillenuve: chloe and halle are angels beyo
#         |                 | ncé really did bless them #mtvawards  https://t.co
#         |                 | /y2fDHMj3rs
#  2630   |       MTV       | RT @MTV: 🚨 #DolanTwins alert 🚨 Hang with @graysond
#         |                 | olan and @ethandolan at the #MTVAwards tonight at
#         |                 | 9/8c! 😘 https://t.co/2pqo3imKGr
#  2463   |       MTV       | RT @MTV: The Losers' Club? More like the WINNERS C
#         |                 | LUB ☺️☺️The cast of #ITMovie wins Best On-Screen T
#         |                 | eam at the #MTVAwards https://t.co/lq5u…
#   950   |       MTV       | RT @MTV: Congrats to my bb @madelainepetsch on win
#         |                 | ning Best Scene Stealer at the #MTVAwards. https:/
#         |                 | /t.co/FYvWst0iI7
#   727   |   cxhupdates    | RT @cxhupdates: Chloe and Halle performing at the
#         |                 | #MTVAwards https://t.co/cZHo1RiYxU
#   346   |   MTVteenwolf   | RT @MTVteenwolf: Here's to hoping that the weather
#         |                 |  at this Monday's #MTVAwards isn't as London-like
#         |                 | as it was for @daniel_sharman in 2013…
#   259   | RuPaulsDragRace | RT @RuPaulsDragRace: Finish her! 👊 Fatality! ☠️ Ka
#         |                 | tya wins! 🏆\\@AlyssaEdwards_1, @katya_zamo, and @t
#         |                 | rixiemattel had an absolute kiki watchi…
#   245   |      MTVLA      | RT @MTVLA: EL DÚO MÁS TIERNO DE TODOS LOS TIEMPOS!
#         |                 |  @RealHughJackman &amp; Dafne Keen #MTVAwards 🙌🏼 h
#         |                 | ttps://t.co/3wGzclQYAd
